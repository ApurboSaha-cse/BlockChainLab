# %% [markdown]
# Program 1: Program for Implementing Blockchain in Python

# %%
import hashlib

class Block:
    def __init__(self, data, previous_hash):
        self.data = data
        self.previous_hash = previous_hash
        self.nonce = 0
        self.hash = self.calculate_hash()

    # Calculate the SHA256 hash of the block
    def calculate_hash(self):
        hash_string = str(self.data) + str(self.previous_hash) + str(self.nonce)
        return hashlib.sha256(hash_string.encode()).hexdigest()

    # Proof of work algorithm
    def mine_block(self, difficulty):
        while self.hash[0:difficulty] != '0' * difficulty:
            self.nonce += 1
            self.hash = self.calculate_hash()

# Define the blockchain structure
class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]
        self.difficulty = 2

    # Create the first (genesis) block
    def create_genesis_block(self):
        return Block("Genesis Block", "0")

    # Get the last block in the blockchain
    def get_last_block(self):
        return self.chain[-1]

    # Add a new block to the blockchain
    def add_block(self, new_block):
        new_block.previous_hash = self.get_last_block().hash
        new_block.mine_block(self.difficulty)
        self.chain.append(new_block)

# Test the blockchain
blockchain = Blockchain()
blockchain.add_block(Block("Block 1", ""))
blockchain.add_block(Block("Block 2", ""))
blockchain.add_block(Block("Block 3", ""))

# Print the blockchain
for block in blockchain.chain:
    print("Block data: ", block.data)
    print("Block hash: ", block.hash)
# Out:
# Block data:  Genesis Block
# Block hash:  8d59df74150242faafaaba4d1632c6e31e4e470c175c2c90c168ec6a4500fc3e
# Block data:  Block 1
# Block hash:  000ed2983b9272d8536e07beba4678ffba9ac7b3a62d55e31e1843da25144efa
# Block data:  Block 2
# Block hash:  00172655ca0210f6bf693a27363c99a0c3108ad9257c0fc3fc14dd01e481d34e
# Block data:  Block 3
# Block hash:  007eb6b94b1874d4bfbeef92412df242bb835183d9860c80750791e99ac3be60

# %% [markdown]
# Program 2: Write a program in Python for mining a new block in a blockchain, and print the values of the new block.

# %%
import datetime

class BlockNode:
    def __init__(self, data, timestamp=None):
        self.data = data
        self.timestamp = timestamp or datetime.datetime.now()
        self.next = None


class Blockchain:
    def __init__(self):
        self.head = None

    def add_block(self, data):
        new_block = BlockNode(data)
        if self.head is None:
            self.head = new_block
        else:
            current_block = self.head
            while current_block.next:
                current_block = current_block.next
            current_block.next = new_block

    def mine_block(self, data):
        new_block = BlockNode(data)
        new_block.next = self.head
        self.head = new_block

    def traverse(self):
        current_block = self.head
        while current_block:
            print(f"Block Data: {current_block.data}")
            print(f"Timestamp: {current_block.timestamp}")
            print()
            current_block = current_block.next


# Create a new blockchain
blockchain = Blockchain()

# Add blocks to the chain
blockchain.add_block("Block 1")
blockchain.add_block("Block 2")
blockchain.add_block("Block 3")

# Traverse the blockchain and print the data
print("Blockchain before mining new block:")
blockchain.traverse()

# Mine a new block and add it to the chain
blockchain.mine_block("Block 4")

# Traverse the blockchain again after mining new block
print("Blockchain after mining new block:")
blockchain.traverse()
# Out:
# Blockchain before mining new block:
# Block Data: Block 1
# Timestamp: 2025-01-21 22:56:25.625618
#
# Block Data: Block 2
# Timestamp: 2025-01-21 22:56:25.625618
#
# Block Data: Block 3
# Timestamp: 2025-01-21 22:56:25.625618
#
# Blockchain after mining new block:
# Block Data: Block 4
# Timestamp: 2025-01-21 22:56:25.625618
#
# Block Data: Block 1
# Timestamp: 2025-01-21 22:56:25.625618
#
# Block Data: Block 2
# Timestamp: 2025-01-21 22:56:25.625618
#
# Block Data: Block 3
# Timestamp: 2025-01-21 22:56:25.625618

# %% [markdown]
# Program 3: Write a program in Python to create four new blocks in a blockchain. Traverse the blocks and print the values.

# %%
import hashlib
import datetime

class Block:
    def __init__(self, data, previous_hash):
        self.timestamp = datetime.datetime.now()
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = str(self.timestamp) + str(self.data) + str(self.previous_hash)
        return hashlib.sha256(data_string.encode('utf-8')).hexdigest()

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block("Genesis Block", "0")

    def add_block(self, new_block):
        new_block.previous_hash = self.chain[-1].hash
        self.chain.append(new_block)

    def traverse_chain(self):
        for block in self.chain:
            print("Timestamp:", block.timestamp)
            print("Data:", block.data)
            print("Previous Hash:", block.previous_hash)
            print("Hash:", block.hash)
            print("")

# Create a new blockchain
my_blockchain = Blockchain()

# Add four blocks to the blockchain
my_blockchain.add_block(Block("Transaction 1", ""))
my_blockchain.add_block(Block("Transaction 2", ""))
my_blockchain.add_block(Block("Transaction 3", ""))
my_blockchain.add_block(Block("Transaction 4", ""))

# Traverse the blockchain and print the contents of each block
my_blockchain.traverse_chain()
# Out:
# Timestamp: 2025-01-21 22:58:03.778590
# Data: Genesis Block
# Previous Hash: 0
# Hash: 3b4818e45ad80d7a7f1800ee682cf78062cdd2e16d0cd829067a836a060439a0
#
# Timestamp: 2025-01-21 22:58:03.778590
# Data: Transaction 1
# Previous Hash: 3b4818e45ad80d7a7f1800ee682cf78062cdd2e16d0cd829067a836a060439a0
# Hash: 7cc7aeec56b0965dbbf5c2230746ce5e3738c39cd8f715be1a205b8f758f37a4
#
# Timestamp: 2025-01-21 22:58:03.778590
# Data: Transaction 2
# Previous Hash: 7cc7aeec56b0965dbbf5c2230746ce5e3738c39cd8f715be1a205b8f758f37a4
# Hash: 4065d433a634043db0ac1d65b3dabe5bf0b080abc5bffcb859ba2bf943477783
#
# Timestamp: 2025-01-21 22:58:03.778590
# Data: Transaction 3
# Previous Hash: 4065d433a634043db0ac1d65b3dabe5bf0b080abc5bffcb859ba2bf943477783
# Hash: 1d304daaab29d8da4fa021c144860353ee31652132618cc08d79b40b54bd795e
#
# Timestamp: 2025-01-21 22:58:03.778590
# Data: Transaction 4
# Previous Hash: 1d304daaab29d8da4fa021c144860353ee31652132618cc08d79b40b54bd795e
# Hash: 73d3533d4ab6c81edd51582d4fc295a26456a6dadaa5f05e67f773a5140d3de0

# %% [markdown]
# Program 4: Write a program in Python to implement a blockchain and print the values of all fields as described in etherscan.io

# %%
import hashlib
import datetime

class Block:
    def __init__(self, block_number, transactions, previous_hash, gas_limit, gas_used, miner):
        self.block_number = block_number
        self.timestamp = datetime.datetime.now()
        self.transactions = transactions
        self.previous_hash = previous_hash
        self.gas_limit = gas_limit
        self.gas_used = gas_used
        self.miner = miner
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = (
            str(self.block_number)
            + str(self.timestamp)
            + str(self.transactions)
            + str(self.previous_hash)
            + str(self.gas_limit)
            + str(self.gas_used)
            + str(self.miner)
        )
        return hashlib.sha256(data_string.encode('utf-8')).hexdigest()

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block(0, "Genesis Block", "0", 0, 0, "Genesis Miner")

    def add_block(self, new_block):
        new_block.previous_hash = self.chain[-1].hash
        self.chain.append(new_block)

    def print_block(self, block):
        print("Block Number:", block.block_number)
        print("Timestamp:", block.timestamp)
        print("Transactions:", block.transactions)
        print("Previous Hash:", block.previous_hash)
        print("Gas Limit:", block.gas_limit)
        print("Gas Used:", block.gas_used)
        print("Miner:", block.miner)
        print("Hash:", block.hash)
        print("")

    def traverse_chain(self):
        for block in self.chain:
            self.print_block(block)

# Create a new blockchain
my_blockchain = Blockchain()

# Add three blocks to the blockchain
my_blockchain.add_block(Block(1, "Transaction 1", "", 1000000, 500000, "Miner 1"))
my_blockchain.add_block(Block(2, "Transaction 2", "", 2000000, 1500000, "Miner 2"))
my_blockchain.add_block(Block(3, "Transaction 3", "", 3000000, 2500000, "Miner 3"))

# Traverse the blockchain and print all the fields of each block
my_blockchain.traverse_chain()
# Out:
# Block Number: 0
# Timestamp: 2025-01-28 17:27:59.499601
# Transactions: Genesis Block
# Previous Hash: 0
# Gas Limit: 0
# Gas Used: 0
# Miner: Genesis Miner
# Hash: dcb3d633ed37529831154bd81eb99866b371adef4a103b1f77eb1ec3173f6288
#
# Block Number: 1
# Timestamp: 2025-01-28 17:27:59.499601
# Transactions: Transaction 1
# Previous Hash: dcb3d633ed37529831154bd81eb99866b371adef4a103b1f77eb1ec3173f6288
# Gas Limit: 1000000
# Gas Used: 500000
# Miner: Miner 1
# Hash: d63be02fb770860dd963e7968400e09b7bb5f1e356d45b8014178d60109051aa
#
# Block Number: 2
# Timestamp: 2025-01-28 17:27:59.499601
# Transactions: Transaction 2
# Previous Hash: d63be02fb770860dd963e7968400e09b7bb5f1e356d45b8014178d60109051aa
# Gas Limit: 2000000
# Gas Used: 1500000
# Miner: Miner 2
# Hash: 0febc98bfb395c77b408fd80802dc9609f7347c5662007ca3531e9acd2887d81
#
# Block Number: 3
# Timestamp: 2025-01-28 17:27:59.499601
# Transactions: Transaction 3
# Previous Hash: 0febc98bfb395c77b408fd80802dc9609f7347c5662007ca3531e9acd2887d81
# Gas Limit: 3000000
# Gas Used: 2500000
# Miner: Miner 3
# Hash: 2c103e76c53027738343b7bc20f4a49ea34cd78a8250b038a07382549ca88287

# %% [markdown]
# Program 5: Write a program in Python to implement a blockchain and UTXo (unspent transaction output).

# %%
import hashlib

class UTXO:
    def __init__(self, txid, index, value):
        self.txid = txid
        self.index = index
        self.value = value

    def __str__(self):
        return f"UTXO ({self.txid}:{self.index}) with value {self.value}"

class Transaction:
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __str__(self): 
        return f"Transaction with {len(self.inputs)} inputs and {len(self.outputs)} outputs" 

    def hash(self): 
        # Generating a hash for the transaction 
        tx_input = ''.join([str(inp.txid) + str(inp.index) for inp in self.inputs]) 
        tx_output = ''.join([str(out.value) for out in self.outputs]) 
        tx_data = tx_input + tx_output 
        return hashlib.sha256(tx_data.encode('utf-8')).hexdigest()

# Defining the sample UTXOs and transactions 
utxo1 = UTXO('txid1', 0, 10) 
utxo2 = UTXO('txid2', 1, 20) 

input1 = [utxo1] 
output1 = [UTXO('txid3', 0, 25), UTXO('txid3', 1, 5)] 
tx1 = Transaction(input1, output1) 

input2 = [utxo2] 
output2 = [UTXO('txid4', 0, 15), UTXO('txid4', 1, 5)] 
tx2 = Transaction(input2, output2) 

# Printing the UTXOs and transactions 
print(utxo1) 
print(utxo2) 
print(tx1) 
print(tx2) 

# Generating hashes for the transactions 
print(tx1.hash()) 
print(tx2.hash())
# Out:
# UTXO (txid1:0) with value 10
# UTXO (txid2:1) with value 20
# Transaction with 1 inputs and 2 outputs
# Transaction with 1 inputs and 2 outputs
# fe3230fe9ee48b845306422ff3c8ae3423fe87ea0cffde0f898813ee6adddd4e
# d0b5cddfc541febacd6188b4f15947cc3234e2f590bc3f7cd5a619aa644aa070

# %% [markdown]
# Program 6: Write a program in Python to implement PoW algorithm.

# %%
# Implementation of Proof of Work (PoW) algorithm in Python

import hashlib
import time

class Block:
    def __init__(self, data, previous_hash):
        self.timestamp = time.time()
        self.data = data
        self.previous_hash = previous_hash
        self.nonce = 0
        self.hash = self.generate_hash()

    def generate_hash(self):
        block_contents = str(self.timestamp) + str(self.data) + str(self.previous_hash) + str(self.nonce)
        block_hash = hashlib.sha256(block_contents.encode()).hexdigest()
        return block_hash

    def mine_block(self, difficulty):
        while self.hash[:difficulty] != '0' * difficulty:
            self.nonce += 1
            self.hash = self.generate_hash()
        print("Block mined: {}".format(self.hash))

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]
        self.difficulty = 2

    def create_genesis_block(self):
        return Block("Genesis Block", "0")

    def get_latest_block(self):
        return self.chain[-1]

    def add_block(self, new_block):
        new_block.previous_hash = self.get_latest_block().hash
        new_block.mine_block(self.difficulty)
        self.chain.append(new_block)

    def is_chain_valid(self):
        for i in range(1, len(self.chain)):
            current_block = self.chain[i]
            previous_block = self.chain[i - 1]

            if current_block.hash != current_block.generate_hash():
                return False

            if current_block.previous_hash != previous_block.hash:
                return False

        return True

if __name__ == '__main__':
    blockchain = Blockchain()
    
    print("Mining block 1...")
    block1 = Block("Transaction 1", "")
    blockchain.add_block(block1)

    print("Mining block 2...")
    block2 = Block("Transaction 2", "")
    blockchain.add_block(block2)

    print("Mining block 3...")
    block3 = Block("Transaction 3", "")
    blockchain.add_block(block3)

    print("Is blockchain valid? {}".format(blockchain.is_chain_valid()))

    # Tamper with blockchain
    blockchain.chain[1].data = "Tampered transaction"

    print("Is blockchain valid after tampering? {}".format(blockchain.is_chain_valid()))
# Out:
# Mining block 1...
# Block mined: 009cbcc128670e4331b4ec314a7b1245f013873ff5a806eaed38a4b70ced9d91
# Mining block 2...
# Block mined: 0084624889a1ff06b71ebcce688869133613cc84de06ac56c875d17a61ea6968
# Mining block 3...
# Block mined: 00e625dfd9d8ab026848f8277713491dc9073deab27066a02127a87d1fd51f2e
# Is blockchain valid? True
# Is blockchain valid after tampering? False

# %% [markdown]
# Program 7: Write a program in Python to implement PoS consensus algorithm.

# %%
import hashlib
import time

class Block:
    def __init__(self, data, previous_hash):
        self.timestamp = time.time()
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.generate_hash()

    def generate_hash(self):
        block_contents = str(self.timestamp) + str(self.data) + str(self.previous_hash)
        block_hash = hashlib.sha256(block_contents.encode()).hexdigest()
        return block_hash

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block("Genesis Block", "0")

    def get_latest_block(self):
        return self.chain[-1]

    def add_block(self, new_block):
        new_block.previous_hash = self.get_latest_block().hash
        new_block.hash = new_block.generate_hash()
        self.chain.append(new_block)

    def is_chain_valid(self):
        for i in range(1, len(self.chain)):
            current_block = self.chain[i]
            previous_block = self.chain[i - 1]

            if current_block.hash != current_block.generate_hash():
                return False

            if current_block.previous_hash != previous_block.hash:
                return False

        return True

if __name__ == '__main__':
    blockchain = Blockchain()

    print("Mining block 1...")
    block1 = Block("Transaction 1", "")
    blockchain.add_block(block1)

    print("Mining block 2...")
    block2 = Block("Transaction 2", "")
    blockchain.add_block(block2)

    print("Mining block 3...")
    block3 = Block("Transaction 3", "")
    blockchain.add_block(block3)

    print("Is blockchain valid? {}".format(blockchain.is_chain_valid()))
# Out:
# Mining block 1...
# Mining block 2...
# Mining block 3...
# Is blockchain valid? True

# %% [markdown]
# Program 8: Write a program in Python to Fetch the Latest Block Information from Ethereum Blockchain Using Etherscan API

# %%
import requests 

def get_latest_block(api_key):
    url = "https://api.etherscan.io/api"
    params = {
        "module": "proxy",
        "action": "eth_getBlockByNumber",
        "tag": "latest",
        "boolean": "true",
        "apikey": api_key,
    }

    try:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            return data["result"]
        else:
            print("Request failed with status code:", response.status_code)
    except requests.RequestException as e:
        print("Request failed:", str(e))

    return None

# Replace "YOUR_API_KEY" with your actual API key
api_key = "E34342B4IR3B8RI3K61XG4YKEUT7SR54MM"

latest_block = get_latest_block(api_key)
if latest_block is not None:
    print("Latest block information:")
    print("Block Number:", int(latest_block["number"], 16))
    print("Timestamp:", int(latest_block["timestamp"], 16))
    print("Miner Address:", latest_block["miner"])
    print("Difficulty:", int(latest_block["difficulty"], 16))
    print("Total Difficulty:", int(latest_block["totalDifficulty"], 16))
    print("Gas Limit:", int(latest_block["gasLimit"], 16))
    print("Gas Used:", int(latest_block["gasUsed"], 16))
    print("Transaction Count:", len(latest_block["transactions"]))
    
    print("\nTransactions:")
    for tx in latest_block["transactions"]:
        print("Transaction Hash:", tx["hash"])
        print("From:", tx["from"])
        print("To:", tx["to"])
        print("Value (in Wei):", tx["value"])
        print("-" * 40)  # Formatting separator
else:
    print("Failed to fetch the latest block information.")
# Out:
# Latest block information:
# Block Number: 21722808
# Timestamp: 1738064699
# Miner Address: 0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# Difficulty: 0
# Total Difficulty: 58750003716598352816469
# Gas Limit: 30087829
# Gas Used: 16309372
# Transaction Count: 194
#
# Transactions:
# Transaction Hash: 0xf535cd3c3cdd807d29e202943691dd0c647f34b168628641b5b1778660e7835e
# From: 0x3663036d2cf399cf55bafb9f17aadeb9c0f939cd
# To: 0xb33d999469a7e6b9ebc25a3a05248287b855ed46
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5d15c247463d36d33d9a03376a10429e6210a77e35952d35fee75caa6afde35e
# From: 0x40bbd853b0a1496ea38204cc3b6abe931193a473
# To: 0x3c11f6265ddec22f4d049dde480615735f451646
# Value (in Wei): 0x21c0331d5dc000
# ----------------------------------------
# Transaction Hash: 0x0aefbc9c1374cbd00640e3e75d1955dd760b5d2c9503ee73d4d04ee6bae42b61
# From: 0xb93fdd28fd757f213ad783e1bf81a89fbd641f5a
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xd346eb205c81631b337579fb89ff80f902cd5a9904f162f9a8b862373ab5ca5b
# From: 0x9fb84dfb7a0c414ccbad901d50b7c620a1150a62
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x079fffcd309f72ee11ecb25730ff12586884339eb47a1a0fb6b0757147e7ce8b
# From: 0x3427f1d7d3bd98d3033905b79bf34e3327906640
# To: 0x0000000000001ff3684f28c67538d4d072c22734
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x327a35f159afaae8f7b1d40c6964fc41859e3dbe45823fc71c20f92519704e98
# From: 0x5b39e72613680957b23f86f7b2df36a78fde5a30
# To: 0x31d70b48f653d487981076f02becfbb8f46daf3f
# Value (in Wei): 0x21b5f7c51ccc000
# ----------------------------------------
# Transaction Hash: 0xb5844006c2a7772c5893007f6feab41abaf38121c8e17efaa235d15f2fff8024
# From: 0xe0c9d9f92f34ee837a5b4c19b11cbd504abd9a6f
# To: 0xdef1c0ded9bec7f1a1670819833240f027b25eff
# Value (in Wei): 0xa1bf632b0c39d4
# ----------------------------------------
# Transaction Hash: 0x1eecd54db715113c5b327f6ae036083a27607337b1fb5f65b589bfa8553edad2
# From: 0x4f3c86e0bf79792c318016857b08ba9837e4ec23
# To: 0xd1cd5251da82721941ad2a8f009fb62e72e05e76
# Value (in Wei): 0xa99e17e
# ----------------------------------------
# Transaction Hash: 0xce43b2e15bbee4131a5b0248300fe3d3930a27c1c7aa8d4d21f1afc253c10291
# From: 0xf432572d5ae0946adc2b47d72af49fe4d4e319f8
# To: 0xb544745bd6596c1d835ae13acd98513ee7e5a7a6
# Value (in Wei): 0x824abdd95e3c5b
# ----------------------------------------
# Transaction Hash: 0xdaa466d6a9ba765c1a60ed912bce8ffd142478b3074ffbc610e1def83571c4b0
# From: 0xb97aab5e9694b6957663bd60efb36d0cab45933d
# To: 0x49453605a4df2b27d7aab9527f509f259bcbad6a
# Value (in Wei): 0xd06e6662bf6036
# ----------------------------------------
# Transaction Hash: 0xe3907b859b3c1a4fae3867f5d339bf128c3b010f9732fa02be34985a925e0d92
# From: 0xd230334edc2f8def9f360d4bd4215cfaebb968a7
# To: 0x9b4e8e3d1b2501257e1bd4b438f5a7fd98849b84
# Value (in Wei): 0x1dca42f6c336d000
# ----------------------------------------
# Transaction Hash: 0xd88cf5a83197a8b88d5f73b1c8efc4b34dd6c23c19ffb37e0350bb5c3f528e17
# From: 0x45662198c804d9b6a3dab28a10bd05127fa722d3
# To: 0x055c48651015cf5b21599a4ded8c402fdc718058
# Value (in Wei): 0x16345785d8a0000
# ----------------------------------------
# Transaction Hash: 0x999fab97b25ffa2269c7e356933a7857483bb48ffa84e4a1b267f83033cdacb7
# From: 0xeb6c4be4b92a52e969f4bf405025d997703d5383
# To: 0xb85c9a09a79e92d742f0a8717b1779b97f4a40f7
# Value (in Wei): 0x6f05b59d3b200000
# ----------------------------------------
# Transaction Hash: 0x950e4533dbf32084edd2f5eb92adf41ade8813e2ef2ce4ff836fc5c64eb16530
# From: 0x63ed89c2728726fdfb8958120e15c23d2c7dd69b
# To: 0xa02c49da76a085e4e1ee60a6b920ddbc8db599f4
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xd72eef313afaf1ac8740ff48a5d4fce27653c21a9b1bef00c5557af5a778a642
# From: 0xbe39f4f42b9b0460cc5bd5151e5dbe1e05140663
# To: 0xaea46a60368a7bd060eec7df8cba43b7ef41ad85
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xdd4f3ebd21e85e1bd294509d4197e3db231c97139e848c8b2390f1249fdeef0f
# From: 0x79fb4ebdd543d0927b809b1e8f552f1bf74dec65
# To: 0x06a9ab27c7e2255df1815e6cc0168d7755feb19a
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc0727e513fdfa5819ff109bf08aade051ef4a8f02bb1198d6f437911123d30f4
# From: 0xda8cf15bc458a7b13735e7d04495f8cda53f3205
# To: 0x51c72848c68a965f66fa7a88855f9f7784502a7f
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1ebbc2b0cbb7220eaef929c2c1dce7c122d4193cb943e582f96fc52e1a1d369b
# From: 0xb98c6340a49cc87256435d7fbd795d95c8f25d11
# To: 0x89a99a0a17d37419f99cf8dc5ffa578f3cdb58b5
# Value (in Wei): 0x135b6ae0cc0a6
# ----------------------------------------
# Transaction Hash: 0x4f416912f764d29b8e29900b694d50790b4be8c7aeeb502bc76ba6f814823265
# From: 0x9696f59e4d72e237be84ffd425dcad154bf96976
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x11001801cc60a05ef10b97da13fccbdecc6799753a754c636ac229508480d65c
# From: 0x8ec8380d1c033b3b97410497464f7dc33cd7ec65
# To: 0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xa88de66286c44efe395ae4fb08b79a2d0379183a88703a3544b6750628912a58
# From: 0x9279aa7b633ced7fbf3a3b19bd91ccedecd41b43
# To: 0xb33bd56d4192e8e4e6a02e93eabc732165199346
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5dec0d219aa30ec163d2776f5af2606d07927f1a178d60963aea61ef4935424e
# From: 0xdfd5293d8e347dfe59e90efd55b2956a1343963d
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1d2a49777b79334b58b6c6a86def896ce12d8cb37d7741ba0a187fc1fc557bb8
# From: 0x5041ed759dd4afc3a72b8192c143f72f4724081a
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc795908e3b1eba8be91dba3f1c0dc364ee3cdf90eb21e2215a2da7b5fbfe1c8b
# From: 0x267be1c1d684f78cb4f6a176c4911b741e4ffdc0
# To: 0x7bb6325374ed5074a2b903c97368c4db33038a2d
# Value (in Wei): 0x386b0f3c82dd4c00
# ----------------------------------------
# Transaction Hash: 0xc961bc7d112c3afbb287ed83fab986345dd04990007d4ba264b0359002106b4f
# From: 0x267be1c1d684f78cb4f6a176c4911b741e4ffdc0
# To: 0x7bb6325374ed5074a2b903c97368c4db33038a2d
# Value (in Wei): 0x386b0f3c82dd4c00
# ----------------------------------------
# Transaction Hash: 0x9cf90dcccad23ae782ed7016581d48c7cb1e72ef28743e4c7d001824bc605dde
# From: 0xeacd5d86a9f3764a2873cc8efba0afb9b484a187
# To: 0x7ea906bff881bdfdd6b38f97093855e4c12d7054
# Value (in Wei): 0x56a42eb0f18e453
# ----------------------------------------
# Transaction Hash: 0xa8ab67b3c2f6b2c8ae0bfa1087ef60a3aeb7e40e921cba265b4a3c5a47b48cd1
# From: 0x72fc8c1b92e333cc56a52e4b8d5a9211f1b3cb2f
# To: 0x9c7beba8f6ef6643abd725e45a4e8387ef260649
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x103ed1bbc51fa8370a26cbc88494d575351d99fe6b92866d9cecfda622cb404b
# From: 0x28c6c06298d514db089934071355e5743bf21d60
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc807b1ad6e4ad9f9efe0e156e4d0fc6e9bb03a1c1438161924db46148d12e264
# From: 0x28c6c06298d514db089934071355e5743bf21d60
# To: 0xc4441c2be5d8fa8126822b9929ca0b81ea0de38e
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf591b8ef82eb047c2f64947fb61d4ee0ac0126475c69b5f2040f126c74ca359a
# From: 0xf89d7b9c864f589bbf53a82105107622b35eaa40
# To: 0xa0ef786bf476fe0810408caba05e536ac800ff86
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x965abd0a4d87f16192ea66bfe0a3479d8a842e7dd9703723c74eb412e140600d
# From: 0xf214798a8af12ad98e173171ee2d8d7ea11ce75c
# To: 0x1f9840a85d5af5bf1d1762f925bdaddc4201f984
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xe4fe522d61d9d39326276aebef170873579c0cebfced97f6e0934d40294a1473
# From: 0x21a31ee1afc51d94c2efccaa2092ad1028285549
# To: 0x113964ca07426fe7ed94c9946dde1ce229e78c97
# Value (in Wei): 0x5376c24fb55000
# ----------------------------------------
# Transaction Hash: 0x258c9b3b44c4683f594b33954eaa6a0d511fc9ef4c208c01ec634b6d3ce007a9
# From: 0x21a31ee1afc51d94c2efccaa2092ad1028285549
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xfaff2ea68bb25df76bd4752a26ac7f6c12becb311036ca777b58315d22026fd7
# From: 0x02a72321573ede25c1ae6503cccf0abb75a1aeb1
# To: 0x10ee383b1407a7443bc3333fcb519bd4751d8d83
# Value (in Wei): 0xb26c136a593c4
# ----------------------------------------
# Transaction Hash: 0x3bec05301a2ef7a4d64da1989b97db529ca53efe20bc3f26cb7c78179b7466bd
# From: 0x21a31ee1afc51d94c2efccaa2092ad1028285549
# To: 0x514910771af9ca656af840dff83e8264ecf986ca
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x35922bef441ce9140a1b3f5b2b34e828e0ac762711527c4fff98d3d2b1428121
# From: 0x28c6c06298d514db089934071355e5743bf21d60
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc0fb5014f02a316f5bf610fc68869ba16f35d9bbe1eb0e2fca13074a969ccc8e
# From: 0xdfd5293d8e347dfe59e90efd55b2956a1343963d
# To: 0xb35a259ca1c33ebaacb6f02886d3d82c73a9671a
# Value (in Wei): 0x1f438daa060000
# ----------------------------------------
# Transaction Hash: 0x8e2cc084831552928f374a988f3bbae63bd8e254c5c6b469835e389febb4e86e
# From: 0x267be1c1d684f78cb4f6a176c4911b741e4ffdc0
# To: 0x840b8f5e5989b82af181e4d00e0f171e7c9a132b
# Value (in Wei): 0x804c9e58f5a000
# ----------------------------------------
# Transaction Hash: 0x3c14228577dc637242df0624c37bfabd511a660004aae88afea9691d748f9980
# From: 0x267be1c1d684f78cb4f6a176c4911b741e4ffdc0
# To: 0x4db7abc861a308b248ec23059fbc75d4351a318d
# Value (in Wei): 0x22cec63b2fd8000
# ----------------------------------------
# Transaction Hash: 0xcb7e90ae55213c7e55cdeea1d842fb349e2f99e52bd403c1b9c11b0f079bf769
# From: 0xdfd5293d8e347dfe59e90efd55b2956a1343963d
# To: 0x31c8eacbffdd875c74b94b077895bd78cf1e64a3
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x6c47c7cd5a572bd78a3ebb694454748077a3fd329bdfc27caac4616201788bc4
# From: 0xdfd5293d8e347dfe59e90efd55b2956a1343963d
# To: 0x5283d291dbcf85356a21ba090e6db59121208b44
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc93f95b14765a490a649b3ed09872784762caa627783f3842c4a3d12806cffa8
# From: 0x18c1b2daea757b148ca1a3d373502153e13010ed
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xfc0ebc06e22394653df4bffad3271385a65ab4b3d45101e8d44b2f7521700e18
# From: 0xbca34ed5875079cc561840f3409a790769821dbc
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x95c29bb255d1d258d9f71d0625f6d69b3c52ff21f25a98ec58b2c33d12772c0b
# From: 0xbca34ed5875079cc561840f3409a790769821dbc
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xe19eb2c40c7715206524fbdfc1955bf7461142ba1bf6888ffa89bdadd4128dee
# From: 0x20145c5e27408b5c1cf2239d0115ee3bbc27cbd7
# To: 0x14fee680690900ba0cccfc76ad70fd1b95d10e16
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x02220f094d2c2796600496c4853271bcb3d86273d2996c07c1b5f6060a4598da
# From: 0x4626881cf95d749980ad2be20a81b32f962d2c3c
# To: 0xb0999731f7c2581844658a9d2ced1be0077b7397
# Value (in Wei): 0x2386f26fc10000
# ----------------------------------------
# Transaction Hash: 0x0d522bcdf0173ade5d8dbf681ec9c3ae92b3969867faa23c6ea7127100caa624
# From: 0xcfcd91af654ee9d08640c5e4089d5d299c6f47e8
# To: 0x4e5846858c8da2149b7185f0569121632270aae8
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5f556ee6b0d435dfec6aee1662b369ccae62b94f0f55f50d20e51be57be6b1b4
# From: 0x23d0c20471a72ff558c6ecb7e935c5a820df7313
# To: 0x881d40237659c251811cec9c364ef91dc08d300c
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5c69728d2edc566e4f4668f5e9125374f2eb10c33c9b833bb293d795aefc4619
# From: 0xc529c863a2158e0d9d13212d08235d212d184998
# To: 0x881d40237659c251811cec9c364ef91dc08d300c
# Value (in Wei): 0x8e1bc9bf04000
# ----------------------------------------
# Transaction Hash: 0xf582ccba02b32136b55520e6e236c2079e0cafa9d7b3aca7023f1e0eccae34d4
# From: 0xe6d8445247b22544cea12029330da417c0d02071
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x14757fa3447a3a7230ee8bd2ea3b4e490e7690a328b46b10c4a078faca6cf8f0
# From: 0xb5d85cbf7cb3ee0d56b3bb207d5fc4b82f43f511
# To: 0xdca4c2766d8a9a947c4d43d47f91432af67b032e
# Value (in Wei): 0x3e9891ad3a0000
# ----------------------------------------
# Transaction Hash: 0x5dc6a47ff25e4259448b6f687265cf91f9d2c1b27cb191962ba3cc34795fdbdc
# From: 0xb5d85cbf7cb3ee0d56b3bb207d5fc4b82f43f511
# To: 0x7372856d1565c58801cc72b489c3ca6375f5dd6b
# Value (in Wei): 0x27147114878000
# ----------------------------------------
# Transaction Hash: 0x88ca87c73f619af055b0422bce91f2ee570e47eacf6beb0831b78eb9607b0139
# From: 0xb5d85cbf7cb3ee0d56b3bb207d5fc4b82f43f511
# To: 0x60560ca504576f5eba23c5ae4802758a873eb5ac
# Value (in Wei): 0x4617f936986b000
# ----------------------------------------
# Transaction Hash: 0xeb671affcefbe97225c8a95e86ab828530791395034ab5e470ac4d2e5f846ca0
# From: 0x39afa0eb36659da44c6153a94b2e547b3c6d28f8
# To: 0x3a10dc1a145da500d5fba38b9ec49c8ff11a981f
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xdda0e71857d47f736ff026ae80e596dfaf9b349fb0625704401def8b4a75a6f9
# From: 0x86e81996242d1dce7fc5f9b9d060bbd3410fc206
# To: 0x807cf9a772d5a3f9cefbc1192e939d62f0d9bd38
# Value (in Wei): 0xff3d68ccaa25
# ----------------------------------------
# Transaction Hash: 0x04c803c28239a706c1bdd88ef93b56d1aba11fe2f54377b706ebf572c74554e1
# From: 0x8b1d49a93a84b5da0917a1ed42d8a3e191c28524
# To: 0x4cb67cfee180b6b73b70c7b3fc162e5fcf6532f1
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf681a3b169e655175b24ec5d195231d56cedbd46c2a563efaefa3d7bd0b3bd42
# From: 0xbf572dbca3bf9fe904c6f34e8e4584e1a831fdde
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xe65e8cca49c4b75d757d93ced6bfbfb8e48878dc036340eb8c974694db39f2c1
# From: 0xb03c6a5de2c4cc34b9f0b0d9732f22d37d428cc8
# To: 0x5790011fa0f12058d14117d49b1e22e10a39532a
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x4a1d0f6152737b4883d7dd91d1955eed8dc986cf6f6e3d75ffcb3e5481e982f3
# From: 0x4c2fe2339928e7b77e16f7b074f1909c9ea623ac
# To: 0x5fdcca53617f4d2b9134b29090c87d01058e27e9
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc805da0f083b6b59af905493b837af5a1d1c2a95a2d7a0d6220643aee686a1c9
# From: 0xf21c3c1a698cc0254063a78a017f82f8da695e72
# To: 0x3f64bb07b6097b4fbdc0322799c83294aed3f2ab
# Value (in Wei): 0x10d701403c4000
# ----------------------------------------
# Transaction Hash: 0x0b934ff6a46a4608d0f08f689ff9278f8d06d7a2fc2f7aa6793f1d567a1a61c3
# From: 0x8fca4ade3a517133ff23ca55cdaea29c78c990b8
# To: 0x6982508145454ce325ddbe47a25d4ec3d2311933
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf73dc657f5cfe8e05feb0c5caa2a9970e8dbdb6eceb35184e4c377f171f72f2a
# From: 0x963737c550e70ffe4d59464542a28604edb2ef9a
# To: 0x1bd51bd5b78c5f03c299f75548172c876b73d193
# Value (in Wei): 0x2b423a220c17f400
# ----------------------------------------
# Transaction Hash: 0xed4cff0bb00c420d1438e05353e81c1bdd532ede09985cc92a0e1c5f6e8eeff6
# From: 0x5f063c79b351a5ba3e6ef46a1d3be1a0224af1d3
# To: 0x16c6521dff6bab339122a0fe25a9116693265353
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x2e572746f2a12a4299b1968b3c9d7480b81b91fcbb059e06c92e8d24ba9a9cca
# From: 0x69cd34d609da3d3a2635d4dba334130babdc898b
# To: 0x06450dee7fd2fb8e39061434babcfc05599a6fb8
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x38a67b5fcf310469f2b3770d227434ce82bfa8adb9634e5a8b55168c47f32857
# From: 0x9594f9a7cae45fe7319e9ec46382e17901ffd426
# To: 0xf3de3c0d654fda23dad170f0f320a92172509127
# Value (in Wei): 0x38d7ea4c68000
# ----------------------------------------
# Transaction Hash: 0x4927388a4ffb82599ca1d99305056ea1811c75a562d74b0d24026ad852fb075b
# From: 0xeba37977b08ca2f54180180c1538883571f4f967
# To: 0xf203ca1769ca8e9e8fe1da9d147db68b6c919817
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x67665cb7f1d1b989172edc26797dafbb804d867c5fe295d04d81688fa38dd0f2
# From: 0x8634200b662d05826d7d48efe95f836e138f5b27
# To: 0xf3de3c0d654fda23dad170f0f320a92172509127
# Value (in Wei): 0x1717b72f0a4000
# ----------------------------------------
# Transaction Hash: 0x914fab5deefd61c2000880d22267180d1ab571c77c5098c7dbea91825db059db
# From: 0xac0d6429ecb426783b001dabb046f8c4b0e912c3
# To: 0xf3de3c0d654fda23dad170f0f320a92172509127
# Value (in Wei): 0x6651728988000
# ----------------------------------------
# Transaction Hash: 0xd3508afe47761215b3fd792336127dedc7cd0d25d4a5b95f74ed5713229ffc2d
# From: 0xda3f3a9929f2e90e86bbfa6a2189720020930d96
# To: 0x0000000000a39bb272e79075ade125fd351887ac
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5a8c917ce96345cefabde4770659e680c7076052b2e59b8d3c78ccbd2bb25566
# From: 0x4812024f3f61853b708c9132a755ae924053a66e
# To: 0x38d43a6cb8da0e855a42fb6b0733a0498531d774
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xb26ef31c3e39942547781a8a1b4799a4e1d7e8cb5a3f36e2c81b7adb0db19650
# From: 0xc863ba1bb1d81816a795b3f94c77528292da7e0d
# To: 0x0000000000000068f116a894984e2db1123eb395
# Value (in Wei): 0x49e57d63540000
# ----------------------------------------
# Transaction Hash: 0xefefdacec3fb4eebb7c6408f77709fedf71615e6d9d3f3c9e3e34f011db89e42
# From: 0x56e5b821c428c1aac6195955a3da1dce63b7cf62
# To: 0xd263abe5a36a3e14e4b708406c267fe75280c7fa
# Value (in Wei): 0x3f9f2b9fbb1f99
# ----------------------------------------
# Transaction Hash: 0x2dee6426ee22be9331a86548d7bd826b65a80a09b345cfa19cf4c03cb13a9004
# From: 0xa1f3b79f9d3b3daace2e09108b54a921dd1966a3
# To: 0x7facf273f06c4ee859f197efbc8bf1ab6fb82323
# Value (in Wei): 0x11c37937e08000
# ----------------------------------------
# Transaction Hash: 0x165d4c823894e80159c29c0453a9007141a5d0dbbead4381c7e6e6a8b55f2ff4
# From: 0xe460787f285084fd15fbaf0b162b2a3f95ffb7a5
# To: 0x89ad4ca7e2eaec0408e67384372d3b26ef8eafcd
# Value (in Wei): 0x258586a645d3000
# ----------------------------------------
# Transaction Hash: 0xa44cb076f2f9e5d9912e301fc1386846886987c34d2f5cfaeea6a3f918727505
# From: 0xc4c834713cadcc8df54ab65b3401a1c1e41f16bc
# To: 0xd377855652a21468e9dac00695c3bdef8211c995
# Value (in Wei): 0x24f2beb1aa000
# ----------------------------------------
# Transaction Hash: 0xe1aee14c9d2ebe99c95888584bef49ae29912eb22e6b2c2907aa85f97d118c48
# From: 0x7ec98aafe9795cfc4dd654023aa226d817256a1a
# To: 0x76a0e27618462bdac7a29104bdcfff4e6bfcea2d
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xec4e8a2e2ab5473a6a5d088951a0567c10627a947b740e39adb3484423e0c5ff
# From: 0x53566c2146df171cd629f70d19718744107aaa75
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x9316fb739b12bb24641cce177916e8c187003e3cb394ce2ba8a67b6ce5500727
# From: 0xb75529ff280da1e5b569764a7ee1f5f15424213a
# To: 0x0000000000000068f116a894984e2db1123eb395
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xd91427a3c8d07b45f326f42e112afb932f9c8f2df17f58b46990da977122f9e4
# From: 0x61f31b0b34a86262d3f81498130099ca0873bf5f
# To: 0x76a0e27618462bdac7a29104bdcfff4e6bfcea2d
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x418d1c6802b05dc30b87b8a00cab22e0cb81d2c5fb10e43b76f7b754588aa20f
# From: 0x5d777ddc2c2834c1271bbbc4fa58007c3c541e4d
# To: 0x0000000000a39bb272e79075ade125fd351887ac
# Value (in Wei): 0x6ccd46763f10000
# ----------------------------------------
# Transaction Hash: 0x91a02ed1e6a5b72fbe766c406429c6664877b7c2463ba135310b3486552f88f0
# From: 0x46fb97dc4c23ed01b8abf6420c01b3fad20dffdd
# To: 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# Value (in Wei): 0x2c68af0bb140000
# ----------------------------------------
# Transaction Hash: 0xc61cfaea34fb250414e0cea0c4f23f1aa322c6d650b8562610590e46758df846
# From: 0x3bb8bf82794a51f690fb6ae0aa40eab0232996f0
# To: 0xd396ca541f501f5d303166c509e2045848df356b
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xebacf61cbe731da50829bc928f7b3d0fa59506a77bfe7d86446f7ed2fe137a5c
# From: 0x99ad3178823bd657fec433215217f9a0a9209cd6
# To: 0xe636f94a71ec52cc61ef21787ae351ad832347b7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x97e46749fa607475462d465e8ee8f6cb13f7a158d7e8d831f2b9dfdc02153905
# From: 0x0ac3503b2aa1db06b883d7600b10e5dd9c026b4a
# To: 0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xb867e3f8cc0b4c4e55be0725a2d165d4fcbcdcc17c409536e2b6277565ed75bd
# From: 0xc12a52eead60100a9a75eb4702797df15fccf666
# To: 0x730a5e2acebccaa5e9095723b3cb862739da793c
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x2680da5f60b9e465068838248b61c9d16c82e64473825ca4886640b99835d64b
# From: 0xea6b0532f019756646c1e509b749fcbcf11dc3cb
# To: 0x35cea9e57a393ac66aaa7e25c391d52c74b5648f
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x987fd7be53c91348a2694862bfaa8d74ff554644a7d33f8b2c0f0a1a20042cf0
# From: 0x5a117e43c85fc5a874414de4e0e94f1d029b6b07
# To: 0x2565ae0385659badcada1031db704442e1b69982
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x4d94c9218eb6855ea84af65ef822391d5b5d5a61742dfc200c722ea30c30602e
# From: 0x1f84833dcb4e7421fe691cb64369580c1e48b287
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf2f247e0624df7e22bb50fa6f43c074e298a849d4e6c423b266a89e42a03ae05
# From: 0xb0f72521d24ff2142c0a5e181499493962d2bb9f
# To: 0xde6aceaf7f2dceb3d425643c5f85351f2b38fcde
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x7e5400338872a7104050ba9319745d0673890ebb1e9b3e5402c495a71e0ee6b8
# From: 0x42431ec142bf0849ead2ec736bf6bd3911867b99
# To: 0x6c410cf0b8c113dc6a7641b431390b11d5515082
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xfa83a319a6260c48849deb51b9555dffffc8d9847ae259f252a53227dacae563
# From: 0xa58dc7e628c29c88942770aef4082728a8ac3f56
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x16ed95709f90738cf246cbe2c7440505833c52149f101d2bcbba71fa932a0563
# From: 0x42f9614eae7f50d13ddf6264124de2cc7ad24844
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1133ed95700429228ef312f1dbda8bb6c5556a8a4f790f805bf58f13574854c4
# From: 0xf70da97812cb96acdf810712aa562db8dfa3dbef
# To: 0x3844e1457a78b26d9ec0ab301caa651b28933cef
# Value (in Wei): 0x54db7e315b86c
# ----------------------------------------
# Transaction Hash: 0xa79dc54017fec2b300f7295efe0ea6b1ddaffd0bcbfdc5fc7e25a5ef60190326
# From: 0xf70da97812cb96acdf810712aa562db8dfa3dbef
# To: 0x70636ce6dd97bcb283b7ed2197a92094b9c14dab
# Value (in Wei): 0x108ab55a7a849f
# ----------------------------------------
# Transaction Hash: 0x638ec1920e3d6e694a2c9a36ea24dc02dda176289fe23b3278936e5f671821e4
# From: 0x44609982b2e83ca5c348bba453bfa8363e8a2c22
# To: 0x2751f07ac93b9ee962db3ec7172a6bf5f89232c7
# Value (in Wei): 0xb2b2ec7fb2cc
# ----------------------------------------
# Transaction Hash: 0xf4782b7a4fab685ed4d5ca5ae81776e31b67927ecf17f350169cd1538fcfbcf0
# From: 0xd359ad316ed9697f01ebafd639574470e57ba86d
# To: 0x322cf37ab2ca9be1e2cd9f9ee27c2a9012aabcd1
# Value (in Wei): 0x3f5effd95a6a0
# ----------------------------------------
# Transaction Hash: 0xc7f79ed72eb1eead8c19f6acace6f19df7d1cfc15ef49ea720bc55fba1fbc7a5
# From: 0x8875664714fb98d13a6ca2a26740d140c4311f15
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x9773496b012b018e08c9732eeeb660a42fcaa8133af057b41bca2399afad3bac
# From: 0xaee246556844d01551a69ab579fbcae3b0afb025
# To: 0xf3de3c0d654fda23dad170f0f320a92172509127
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xa523201a6e9753e03299427ff13a9ae5feb34274b6cc08c4acf02d3578781be7
# From: 0xbc7f3b52fcad3811dd92accf52f2b035425ef414
# To: 0x037a54aab062628c9bbae1fdb1583c195585fe41
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xfda1e8ee4d118a03443817568d75cada6c8a196960c2b8ca84d6dbd99ebbfc01
# From: 0x2bf70833e66ffa568ccf70618b5e64dc3c4d4c7c
# To: 0x4095f064b8d3c3548a3bebfd0bbfd04750e30077
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1c109b007aafd726b5b490efb8000ceca541af8d9fde5efce83b4f32c7e410c8
# From: 0xd1f7112354055160d58fa1b1e7cfd15c0bfee464
# To: 0xe3985e6b61b814f7cdb188766562ba71b446b46d
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x19d9371dd04e176bcabab7efc941f75fcbfdff636b257da1bef7d6bdafb72a01
# From: 0x5b59c45d5f32ac3a791c5b33e45a270c7dd8cfc4
# To: 0x683a609af624751c7c3f2ba69fbe75346f4761fb
# Value (in Wei): 0x10f21492028d6
# ----------------------------------------
# Transaction Hash: 0xa8321fc4e7c2ac61c1dda74ccc6a2a382fa0db8627e0f02d03a54598dc9c2bd0
# From: 0x26c50e673fca05131c9b9f23d213b977d9a34c77
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x0ac1f9aaa9ba6c95583d9a72060a4a3db348736618a8fc9a538ea74aeb72c189
# From: 0x852dc1c875f0117ea0808610010893e4c576b6a9
# To: 0x84ce5dc7deb6c6932f661f0b7f3c865a31657881
# Value (in Wei): 0x21f1aa3e982bce
# ----------------------------------------
# Transaction Hash: 0xd87392869051600efac366d88c628d903a746515121cbbbaf84dad96e2ddbbde
# From: 0x73ac57a35298abd7a35ec60f1de46d67b0977af2
# To: 0x9aaaab7110331c5a51751aa7d4018f3bd05bb66d
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x9bd326f8c3f021c26a8a710751ded98a9d09fc5f2e2720c5aa034366c6b1f325
# From: 0xf01cc1a624e5b9821d16eaf84b6504771763bd35
# To: 0xe22d09c86155423d58352e2298865f527595e171
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x3c2802a1ac0cc665e2e48e7b6537a278be8e1fc5c3d2daab996b32096d04b63f
# From: 0x74b0e133bee3384dfcfa60b31d85d8e2062de811
# To: 0x77598b7b036b01a0c4761dc8981eeef1e1e0e6f2
# Value (in Wei): 0x64c92eae3d5800
# ----------------------------------------
# Transaction Hash: 0x007087eb983b42d3c72ab2d8453a50536ee5e401ce21f024e8c5e56eb0bda789
# From: 0x74b0e133bee3384dfcfa60b31d85d8e2062de811
# To: 0xa0cb6843d3272857559c2fa85bdd951501a78a8a
# Value (in Wei): 0x11024bfd53a000
# ----------------------------------------
# Transaction Hash: 0xdb3b966d834bafdb21b7d920a91ef1c89c405cd75f9542c0347b26e03d8f06d3
# From: 0xb6cfa523744e161c453117e78cb74fadd817f9b8
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x72fcb5fc434964b869eec290bdd01f3941602763cbb2ea2328346910baf402bd
# From: 0x1689a089aa12d6cbbd88bc2755e4c192f8702000
# To: 0x2c7aed9e2538606e785733791223b74098927947
# Value (in Wei): 0x3646aacb29e30
# ----------------------------------------
# Transaction Hash: 0xe38a2ccf5c25a7744f1a26088663ffb5c1071f1ffb8461fd62fbeb31e0cebe5a
# From: 0x4cc68f7cb6151809cf9ed8abb62b18860f7f904f
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x38468e0ad93c8fca6c3c05558ad9916e454c46428b0114bf17014db5dd4f24e5
# From: 0x403c865c804e82bc250af400dd8ed36f88dd362f
# To: 0xa5f565650890fba1824ee0f21ebbbf660a179934
# Value (in Wei): 0x39b7ae2971700
# ----------------------------------------
# Transaction Hash: 0xc3eedcccc80e6dbbfdb5d1d3f4b180e9aae237ca9c6c62e4334d85ca512552dc
# From: 0xc8616b4ec09128cdff39d6e4b9ac86eec471d5f2
# To: 0xa84f95eb3dabdc1bbd613709ef5f2fd42ce5be8d
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x0d353342c86e8b28664f115030aba7a7038dc40aa7cdf570c148765a48b57ac2
# From: 0x86453865b209af4b09b043f0fe6e5bec5601692e
# To: 0xaea46a60368a7bd060eec7df8cba43b7ef41ad85
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x0865e77bcb4bd987f5ae0408706050678b0551b3bc21a017d447fd0d2e145d78
# From: 0xb23360ccdd9ed1b15d45e5d3824bb409c8d7c460
# To: 0x971a1ac254d261ce1d74893b8109802129016511
# Value (in Wei): 0x14e64add5c5f800
# ----------------------------------------
# Transaction Hash: 0x36b2b3e559dcc79978cc7a081af4f4333a7f281eeb984c5e5ebf5b6aaf6d4707
# From: 0x2b3fed49557bd88f78b898684f82fbb355305dbb
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5216640698d456a827c7c9a673a66dc1755c5032c134672ba6136f8afe0f7d34
# From: 0xaf7415c61779bb928d2b5ceb9be1b9c1c2ff88e3
# To: 0x7a250d5630b4cf539739df2c5dacb4c659f2488d
# Value (in Wei): 0x4269ddd8451bfe9
# ----------------------------------------
# Transaction Hash: 0xb34fceead3a3bf01d868b6b020c511a30afa3e0e1034b268286a5ce5c8dee300
# From: 0x593c6a5eab02d7d6f8c8411d86409dc7e9e31188
# To: 0x4e5846858c8da2149b7185f0569121632270aae8
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x82285c6ae294b5c1a72b3615f8e38a1dd071c49f7676c3765d61773aada85bd9
# From: 0x622a3dbb869c6b400ec4ceedb842a5cf2956995d
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x91bae8113cb6d026e209006b6015757e4c4188e7eeeb1de2cddc00fb53009f81
# From: 0xc70ae19b5feaa5c19f576e621d2bad9771864fe2
# To: 0xf338cad020d506e8e3d9b4854986e0ece6c23640
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x89c344b04ff27e040b5ef9782060bd83c29b749c46a3083fd9045c415248ecd4
# From: 0x316d2e43270ff4091ca5d269c0e5cd8363524c91
# To: 0xa9f9bf2b643348c0884f2eba4f712e833da9a2b8
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x8fb3025d017794db240f9fb698350852775aa3b1e8ab345cb6270802766defda
# From: 0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# To: 0x965df5ff6116c395187e288e5c87fb96cfb8141c
# Value (in Wei): 0xc4eff9285d8
# ----------------------------------------
# Transaction Hash: 0x30a21579ce5d5034f4b072f62ff705615957f9909db317d6e3d04818b6f33ed1
# From: 0x5cbefbedaeccb3cecdb729c82da3c8fbf0f9c204
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x135fb37bda86524838290b58d512b87453eb993e623b237c179e198e8b864ac1
# From: 0xb4799b5a3e96ae8c4f8f8d9bd91add7f7de054f6
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x33e174e22c45c02a81e0fdb01f5d77bfa04a7a4c8a8a8ce99f1aa372e7ca9a6c
# From: 0x2d27a72b5f00ef46c4c8cd76b34cae69180db3aa
# To: 0x0000000000001ff3684f28c67538d4d072c22734
# Value (in Wei): 0x2f44074af1812c
# ----------------------------------------
# Transaction Hash: 0xc84a1e2b5a005086851b5031a8fb7b9bb22cab66d9dbe45757803ca301ebf775
# From: 0x43ad7dc12d941126073ad40151e1670621faddc0
# To: 0xa2cd3d43c775978a96bdbf12d733d5a1ed94fb18
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc8c48c3c7e0841badb84ea9d1fa269781d0f42ef074abc7ff215bbee095c1ac8
# From: 0x0bbc60e4abca38e6abc78ce86998b63f073a919e
# To: 0x6d1d1ebe7da598194293784252659e862d55b52c
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x5323be57a8c41cad6e52a7d0e1a5fab6098bc5b45073d1073d01606ef419c25b
# From: 0x40a2badf8adaa9a90d813077336e2d52d9cbef80
# To: 0x8300ef50e58581d3381d3f9c2ccf7bca7fee1b3a
# Value (in Wei): 0xf476444aab6400
# ----------------------------------------
# Transaction Hash: 0x13b830cd01384434b3091d5e0c7c20c2c6c86334bf26c28b468943eaa7d9816d
# From: 0xfb19ffd1ff9316b7f5bba076ef4b78e4bbedf4e1
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x8f872d57d7992741ecdd54613632b10f8e13cb2828e77ebb57ef2c2e26d2c009
# From: 0x681070b73a70952e6b42cfdc0c29d1560739182a
# To: 0x640cb7201810bc920835a598248c4fe4898bb5e0
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc23c3cf625b37b6630bb95b07214a1a945feb45d635d045fb4246d7a11c3857b
# From: 0x18e6fb96f6b5f0a43a6e4a92939bcd69872d294d
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x23dca5247d5b7a3b8b0f33d067ac640e6bed962d5125a688c868bd1be06be76f
# From: 0x9cebc28c566e78afd1ac580fb8a281b823a46d61
# To: 0x22ce84a7f86662b78e49c6ec9e51d60fdde7b70a
# Value (in Wei): 0x45781719795c00
# ----------------------------------------
# Transaction Hash: 0x738e0b6fc39edd79421c9c8e816104aac1b26898c59eb74e2f610d369d5ccccb
# From: 0xdc270bf5fb6ca784be1887cc2be463aa7efbc0bb
# To: 0xeff6cb8b614999d130e537751ee99724d01aa167
# Value (in Wei): 0x3320
# ----------------------------------------
# Transaction Hash: 0x9b7f27da29683086ba5866ae2f9d03f5f931be445111efa3f661491d824028d7
# From: 0xdfb02ad9eb056029445c216c3aca2ab98a6077e7
# To: 0xa532883dd6407372053c31ee2387176d1a2a3bfb
# Value (in Wei): 0x1c6bf526340000
# ----------------------------------------
# Transaction Hash: 0x73e58a9d6314ae436d434b91be9bdc798581754d2d9ed071369be4433a61a880
# From: 0x622a3dbb869c6b400ec4ceedb842a5cf2956995d
# To: 0x1111111254eeb25477b68fb85ed929f73a960582
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1ba3511eadbc631d041cbb57e3e48b8f59d0419bb8da41c2efcb6d0337c4323c
# From: 0xa6c3272faeff27b9e8d6d9c8a791224f45bf531b
# To: 0x1111111254eeb25477b68fb85ed929f73a960582
# Value (in Wei): 0xbda2979392bf61c
# ----------------------------------------
# Transaction Hash: 0xbfac61a3bcd7ae1245ae26d825967be896b0eb85190a4f1da97605b37888e621
# From: 0xdab273f37fb32d2b87949205a8ff3009ee0cbd0b
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x8d9df4e99d2d816e52722f452c6c1e25732d74ca9c2794385398599d25af60fe
# From: 0xf4189c765acfbd7d3b2e92f51c5e2ac833404c64
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xbde919c99c89a9dca163a2310c10fffadb90ce209384578bfa3bc3cc3d007cc2
# From: 0xc1ee6f65daa8554fb3d25d8ecfcf76075ccea6e6
# To: 0xb956fb482e52ba26ef164e5159bfa02b135bfba0
# Value (in Wei): 0x2baec01a96308400
# ----------------------------------------
# Transaction Hash: 0xc9c49631498ff387d718588f0b66e6de9fcdbed6d179617e4f6baebbdbb9e739
# From: 0x2ac5178edec1fccfdd593837e2cac5dbc61aead1
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x87a6882713c5c3731fcaf8c44303224eb3ccf58a8502a1a80d46a6398d3a7f89
# From: 0x6926e90411c5c62ee7733c1f665d19cdb68750b1
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf19cf2a1333472ccc08c6d754a8c76e4ab58caffec78120e39761778dbe94eea
# From: 0x8d09ab4cd6e11a42a1b9ec7e05eac1a32c6dad2b
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xf9f72c1d6b2993f1852343bb64d381f597257fb78d252f7ce8657d6b4c128f73
# From: 0xe22619f6d538de6e0b6c1845174d45e90cbd3576
# To: 0xb19fbcdbd529aabc8324745f34109e98e930fccc
# Value (in Wei): 0x10f6d652cd70000
# ----------------------------------------
# Transaction Hash: 0x3e9851bbc708b7b9140100890618cbba2022195c609fc41bddaf2836f87ae50c
# From: 0xd6f92811883708b16c8cd99179e1b06b97f9c163
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x4496d6fa065fb864434d75050067f535b3cb99a93aacd72809fa17ed56dc5102
# From: 0xf0fb649167562f9c3f3443b1b838bec9843870a6
# To: 0x3d2ee13ab157c0e2a70b03c7330941395266b49c
# Value (in Wei): 0x7c8b73b4dedef8
# ----------------------------------------
# Transaction Hash: 0x397412bfb7d545b090e05e9fa59b3ba3e8929764c8459522e000c8453e26b98e
# From: 0x230981f957cf1e1e8b4c2a6e83243edd70793532
# To: 0x34f5acfb70ca6d9988fac1cadbf871a589bc1509
# Value (in Wei): 0x2386f26fc10000
# ----------------------------------------
# Transaction Hash: 0xf9be87d920589792e2fc2eff1a051ee563904f9b04a63497d7454e3166de0d67
# From: 0x2541755ce14edfb61c89edf4262f3d13945e509d
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x4ffe5c26e856ffd0c6f4cdd07ab469c4d7e08b29cb598e99af760a7f857f85e4
# From: 0x66918d7f2afd3fedd938ebbbbb09cbd11839880f
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x23637683c46f48110a4901da708fff2d8b6852a81d68f17ece412e5378bb81b2
# From: 0x268b32d31de59b1a4439475b2dcd11da61eabfa0
# To: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xbe52f285b8622f456eb7fb807af266f1993e96f4ab76a426e3e90b2ac8404f80
# From: 0xc1ee6f65daa8554fb3d25d8ecfcf76075ccea6e6
# To: 0x514910771af9ca656af840dff83e8264ecf986ca
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x8775c5af3e94cb73d9b57c09c83c880833ffde1abe37e7775aa1be861f5f2a85
# From: 0xc1ee6f65daa8554fb3d25d8ecfcf76075ccea6e6
# To: 0x3845badade8e6dff049820680d1f14bd3903a5d0
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x81d87cf1187f810b529e6ad35958ffbcfcd5cab114a2b000a6a24eb41ed93632
# From: 0xd8d6ffe342210057bf4dcc31da28d006f253cef0
# To: 0x514910771af9ca656af840dff83e8264ecf986ca
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xaef6698f3825ce247863259ffb316afabdf6033507816cf3a68267aff3ee0834
# From: 0xfd5c1c3d086a9cc0f21beab6dde3900c9351fc59
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x65f7728b78e433254072bfb92219b9c68d29282d02fc33a12491578e08e49cdb
# From: 0x070cfe1e1b9719e44cc486da496baa899fef88db
# To: 0x0000000000001ff3684f28c67538d4d072c22734
# Value (in Wei): 0xd12f0c4c60000
# ----------------------------------------
# Transaction Hash: 0xaa1a2341b94a4bb15dfcce750d13d18b3b44bfe00e25c1061a1bf3f82a4aee8f
# From: 0x71c426e6606c8a567ee2e219f02f2ea4836d3e73
# To: 0x7f309d46086a08203163c82154ab06fe4ba66c65
# Value (in Wei): 0x6651728988000
# ----------------------------------------
# Transaction Hash: 0xa6bfe47229f6cc9b550e8fbbab63420d08f52aae46be2934f7206b4c73bc5688
# From: 0xa4d4efcce7cdc5b552d974f4f99896a2580c9724
# To: 0x4fbce51c183aea93eaad28064171fb86dbe108b1
# Value (in Wei): 0x7d0e36a818000
# ----------------------------------------
# Transaction Hash: 0xf10d31265976f2fec517c393757feab8d77418879674230ed6f2c8b84b411e98
# From: 0x931e81b03df96789779f1d495f7f875ebda5a565
# To: 0x0000000000001ff3684f28c67538d4d072c22734
# Value (in Wei): 0x51dac207a000
# ----------------------------------------
# Transaction Hash: 0xf08deaffda514ee3a53451e2cadbe00704d2e409535b8e1666f3f9887d6662ee
# From: 0xc46524405603787cdcebdc4dcf23058b820eadbe
# To: 0x4313c378cc91ea583c91387b9216e2c03096b27f
# Value (in Wei): 0x11c37937e080000
# ----------------------------------------
# Transaction Hash: 0x673e4f5231191d75ee1d3a1fb13e27b4d4726a9fa5e6a66d3cdc65affe442234
# From: 0x43ad7dc12d941126073ad40151e1670621faddc0
# To: 0x1111111254eeb25477b68fb85ed929f73a960582
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x9068591460541696c6f45fb24f3f63e925e7c401e17d06749ba1edc40cda5951
# From: 0x811f6d983a5672416577c48f519f4e13e3f94b29
# To: 0xaeb0c00d0125a8a788956ade4f4f12ead9f65ddf
# Value (in Wei): 0x9c51c4521e000
# ----------------------------------------
# Transaction Hash: 0x6409168d3047e0e9c3c90bb311bb30a4373ff5974c2c93a4ec35908762d9f888
# From: 0x6a8e65e992b6591919a2af23db7e91be84393266
# To: 0xb26ff591f44b04e78de18f43b46f8b70c6676984
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xa6cb738af5089324f449ee2a71de1770588a602e31e10fcebea5dc4174dc9105
# From: 0x3f6249c4d782aab00b5e9ab99e090035b80e0c15
# To: 0xb131f4a55907b10d1f0a50d8ab8fa09ec342cd74
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x3eeae52688a4d3d6cf17931bb2072785da0a88de19dd0c6c3294b4bf23a33084
# From: 0x99ebba1220ede88fee09d19ba63b7fdff330f54a
# To: 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# Value (in Wei): 0x2386f26fc10000
# ----------------------------------------
# Transaction Hash: 0x87835f5c97371c63125006c3de523c448bd232dbf4ee633e2d29484686fc3f19
# From: 0xcb7aa6711d86d6ca56dca3d858de9706afb9ff73
# To: 0x2e1a7ef12d0adeebf6009f0aa964cf686364b01f
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x7a1b68e6306c0e69e1ad18c317e45e31ba4c83abf918d230363f1d5ab5280e83
# From: 0xc45f210006ba1d21c51724263001644e4f239acb
# To: 0x5d1fa32ea8932ddaa1d0ef477b9c57b6fefb9054
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x1d0afb8d4c0fc81237410178399b6acb86bf93b43e995d3684c7e20e5be70a21
# From: 0x3f6249c4d782aab00b5e9ab99e090035b80e0c15
# To: 0x0000000000001ff3684f28c67538d4d072c22734
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x91fa56e0cdb9c8ffd5dcb712bde59f13af4c0fe61432fd16616d27cc61db10d9
# From: 0x6b1e5cd84bd83160e904aa4e236659265d499c81
# To: 0x56c526b0159a258887e0d79ec3a80dfb940d0cd7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xaf55b9b177eb37f37c10a8fac7431cb335600fd84bcb2cb800abb9621c579b07
# From: 0x706675177c46a2c08724f7a0c200b7f95d4b1661
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x45990737b49fd6819d321dab65e0e613351325815ca02e33f28b3e02f2c287e9
# From: 0xe93685f3bba03016f02bd1828badd6195988d950
# To: 0x173272739bd7aa6e4e214714048a9fe699453059
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x3535a6b1ce429f3556d72768dfac9d58a7116f32221b4da554dc1044d779eace
# From: 0xa261966d57124f292a6e2caf9ad944da41b37a39
# To: 0xb26ff591f44b04e78de18f43b46f8b70c6676984
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xdb7ef7bb61a6e6402f17e6362c6b660d1252bc448fd8e451f4168441e8576432
# From: 0x6f5dca1ab9588eddd8a85706b19ddde7a5d93c2e
# To: 0x1231deb6f5749ef6ce6943a275a1d3e7486f4eae
# Value (in Wei): 0xa7954270cbff94
# ----------------------------------------
# Transaction Hash: 0x1092274eb8c2ceea71d8e4090423f57a18035bf28e570166e85e523d4bb6ccef
# From: 0x4cb11cc4ce988b40a6c20e798904199519a665fa
# To: 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x7ccd0d116e0c6b5003aff596f45f6899a80b80c81952fa9f579e4872de12c504
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0xeb1afc1138e9c9d7b8fb9ee217fdfc88eca281de
# Value (in Wei): 0x8f33f871fab738
# ----------------------------------------
# Transaction Hash: 0xf9758ccd5d6cbe504b2e418cb7bfe9a3ae454a25b21ae508a3b081b6a0a59df7
# From: 0x6d44861e20d9e192bac4a72a50409f27a81358b5
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xb7e041a2386df3492d1ad3e033ac954153c136639ad086b2a8ce76ba80db2937
# From: 0xd5fbda4c79f38920159fe5f22df9655fde292d47
# To: 0x9c152ffd10b5c4fe76eb62f8d04b011e0c494696
# Value (in Wei): 0xa32ca8b71ea598
# ----------------------------------------
# Transaction Hash: 0x32f8f32488273a04b9812e63dfd0dd0925f41865e1cf37fa1d95f990d9311cb6
# From: 0xcabfcebd15a1138e3ac80249f6807905d2c0973f
# To: 0x45312ea0eff7e09c83cbe249fa1d7598c4c8cd4e
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xc8dcc5aacb9d442aaeb8345de00494dee9ed00c0ceef0e5f54b3a8008d96779f
# From: 0xe3143821143d81ecccb1077191f5a7a5f661d850
# To: 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x3c662093d3d7c298640e9ddd2d62e6a2ed30955c61bb3a4a085ca635fb286e0f
# From: 0x0e54edfa351662186eecf3a58be02cb3f8c1f56e
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x90f71644d779e8ba4706de9ace0f6f32f3ae200c366e5def98259de7d2d73302
# From: 0xe2482d7f8b58830895c953c54500130c4241ec39
# To: 0xa5f565650890fba1824ee0f21ebbbf660a179934
# Value (in Wei): 0xc6f3b40b6c000
# ----------------------------------------
# Transaction Hash: 0xd2f8334daa582fcfceeed70c16cfa90a42291f6b628b7118849c7e5ce0849703
# From: 0xd2674da94285660c9b2353131bef2d8211369a4b
# To: 0x21662b885f36a6d724b3a8921d7448e0a530243f
# Value (in Wei): 0x6d23ad5f8000
# ----------------------------------------
# Transaction Hash: 0x6e03fbc474cb7e3312fd43f26818f15d14e9e70c33147f5a3d678aff4bdd619c
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0xf2e0d8bed9fb8db06505ff2f1a180e8d3f412bea
# Value (in Wei): 0x74b6d29929dcdc
# ----------------------------------------
# Transaction Hash: 0x4fc6dd921ae4e55b47a41eb958bcaac7ff84d8331935848d7aefcf4c6b09a4ce
# From: 0x36efc7c9cf47007c8b40cc12617b1f765265787b
# To: 0x95cef13441be50d20ca4558cc0a27b601ac544e5
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x4b5eb8443f594505593f57c2433de34a180b877dd3e0849bbf354dd881f1bc45
# From: 0xe189d910ab722872a257b7f7dce37c01ca358d65
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0xd3687bcb537cacb53df8e32fb5ba1b32549968ded7c0be8fcfa099e51f7cddd0
# From: 0x7a1d38caca09f408d58837e60e172ea3785f9ff0
# To: 0x9702f20c5295193833e4430266d113b3c41359c3
# Value (in Wei): 0x132f470b98c6c
# ----------------------------------------
# Transaction Hash: 0x7038335599e4297067aded3f53f40d96c9d18e16bcf7147671e2560540e78ecc
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0xe2aa8d43240c5708cdf40e19132926d34d425c54
# Value (in Wei): 0x368fac09044036
# ----------------------------------------
# Transaction Hash: 0xce8163ee3e063428df49ff65230d64fb18773a261147ec266abc3eb6a4d9ac2f
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0xc5b176242cb522477b281e54d50f0ba538ce6176
# Value (in Wei): 0x72119838d132f6
# ----------------------------------------
# Transaction Hash: 0x097239f2865f7178e1710139ef80b917a6e99a546f87017f85afb9dd938febc6
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0x838df5dd23c921550b427dfbf4e90ef96ecb77ce
# Value (in Wei): 0x8a32197bc302a1
# ----------------------------------------
# Transaction Hash: 0x7106ad566b6880c80bacee50ff042e1e95af2dff6262ebfafda34ba0e9bbe18e
# From: 0x8c8d7c46219d9205f056f28fee5950ad564d7465
# To: 0x411c56be2381ea86bf3616f2ae99b96c1afdea52
# Value (in Wei): 0x843031b8cec850
# ----------------------------------------
# Transaction Hash: 0x276d7428b7b1dd144250f7f43c183cc06e4b8993c7ef114539d24c709919246e
# From: 0x558e6fe00878c873eb1de1162eb4ce1df7568042
# To: 0x40b5fa993ca826c2294fd4c67ccce3e400a4dee3
# Value (in Wei): 0x12bf62cdcc0a314
# ----------------------------------------
# Transaction Hash: 0x2d93cfe91c683f68fe0ded2e2050290183823b0d0633202d499768aed0c8e3fc
# From: 0x712cca7f9d38a14e18e785dcce66d8442c90f7c2
# To: 0xdac17f958d2ee523a2206206994597c13d831ec7
# Value (in Wei): 0x0
# ----------------------------------------
# Transaction Hash: 0x9ac168cc58f954a3ffeb9c67bfe4dc7986062f593f7f6ef1b6d251cce522072e
# From: 0x8dbe4031affdd52d9e8ba43248063157a2d44a50
# To: 0xb2ecfe4e4d61f8790bbb9de2d1259b9e2410cea5
# Value (in Wei): 0xddb07829fc000
# ----------------------------------------
# Transaction Hash: 0x0ac764317f5ab2a8da40acae883c81acf514f78d7f9948ca91f0ea205cd64e5e
# From: 0x1c727a55ea3c11b0ab7d3a361fe0f3c47ce6de5d
# To: 0x785051cf81fa346c6e540a1f8ba10b8616ebf0dd
# Value (in Wei): 0x1d09b788821ae2
# ----------------------------------------
# Transaction Hash: 0xbdf3db1acf4082a496e56fd4529b7dbe75af84cb4d0c264b1fa50f4559b61be7
# From: 0x74bd8e5dc38e43610ede9db4bc6fdee8169201ba
# To: 0x3154cf16ccdb4c6d922629664174b904d80f2c35
# Value (in Wei): 0xde0b6b3a7640000
# ----------------------------------------
# Transaction Hash: 0x6f5cb746b6904c9ec47df6c6a67651e75450406b9c66bbd1e04d7c6c477fcec0
# From: 0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5
# To: 0xfc6e18e22ad11592494b3d541ba25af63a807527
# Value (in Wei): 0x40a512b706e209
# ----------------------------------------

# %% [markdown]
# 2.7.2 Python Program that Takes a String and the Desired Number of Leading
# Zeros from the User and Outputs the Input String, the Nonce Value for
# Which the Leading Zeros Puzzle Is Solved, and the Corresponding Hash
# Generated

# %%
import hashlib

def solve_puzzle(string, leading_zeros):
    nonce = 0
    while True:
        nonce_str = str(nonce)
        data = string + nonce_str
        hash_value = hashlib.sha256(data.encode()).hexdigest()
        if hash_value.startswith("0" * leading_zeros):
            return nonce_str, hash_value
        nonce += 1


input_string = input("Enter the String: ")
input_zeros = int(input("Enter the number of leading zeros: "))

nonce_value, hash_result = solve_puzzle(input_string, input_zeros)

print("input String: ", input_string)
print("Nonce value for which the puzzle is solved:", nonce_value)
print("Generated Hash:", hash_result)
# Out:
# input String:  hello
# Nonce value for which the puzzle is solved: 227
# Generated Hash: 001b92541ed0a22b0cb89018b561d895503206c0082c0ecf2d0b7e5182191eed

# %% [markdown]
# 2.7.4 Program in Python that Demonstrates How to Use the SHA-256 Hash
# Function and Its Application in a Simple Blockchain

# %%
import hashlib
import json
from time import time

class Block:
    def __init__(self, index, timestamp, data, previous_hash):
        self.index = index
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()  # Hash should be calculated after initialization

    def calculate_hash(self):
        # Exclude `self.hash` from hash calculation
        block_contents = {
            "index": self.index,
            "timestamp": self.timestamp,
            "data": self.data,
            "previous_hash": self.previous_hash
        }
        block_string = json.dumps(block_contents, sort_keys=True)
        return hashlib.sha256(block_string.encode()).hexdigest()

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block(0, time(), "Genesis Block", "0")

    def add_block(self, data):
        previous_block = self.chain[-1]
        new_block = Block(previous_block.index + 1, time(), data, previous_block.hash)
        self.chain.append(new_block)

    def is_chain_valid(self):
        for i in range(1, len(self.chain)):
            current_block = self.chain[i]
            previous_block = self.chain[i - 1]

            # Recalculate hash and compare
            if current_block.hash != current_block.calculate_hash():
                return False

            # Ensure previous hash reference is correct
            if current_block.previous_hash != previous_block.hash:
                return False

        return True


# Create the blockchain and add blocks
blockchain = Blockchain()
blockchain.add_block("Transaction 1")
blockchain.add_block("Transaction 2")
blockchain.add_block("Transaction 3")

# Validate blockchain before tampering
print("Blockchain is valid:", blockchain.is_chain_valid())

# Attempt to tamper with the second block
blockchain.chain[1].data = "Tampered Transaction"

# Validate blockchain after tampering
print("Blockchain is valid after tampering:", blockchain.is_chain_valid())
# Out:
# Blockchain is valid: True
# Blockchain is valid after tampering: False

# %% [markdown]
# Write a Program in Python to Verify Hash Properties

# %%
import hashlib

# Define a message to hash
message = b"Hello, world!"

# Calculate hash values using different hash functions
md5_hash = hashlib.md5(message).hexdigest()
sha1_hash = hashlib.sha1(message).hexdigest()
sha256_hash = hashlib.sha256(message).hexdigest()

# MD5 Verification
if md5_hash == hashlib.md5(message).hexdigest():
    print("MD5 hash is consistent")
else:
    print("MD5 hash is inconsistent")

if len(md5_hash) == 32:
    print("MD5 hash is 32 characters long")
else:
    print("MD5 hash is not 32 characters long")

# SHA-1 Verification
if sha1_hash == hashlib.sha1(message).hexdigest():
    print("SHA-1 hash is consistent")
else:
    print("SHA-1 hash is inconsistent")

if len(sha1_hash) == 40:
    print("SHA-1 hash is 40 characters long")
else:
    print("SHA-1 hash is not 40 characters long")

# SHA-256 Verification
if sha256_hash == hashlib.sha256(message).hexdigest():
    print("SHA-256 hash is consistent")
else:
    print("SHA-256 hash is inconsistent")

if len(sha256_hash) == 64:
    print("SHA-256 hash is 64 characters long")
else:
    print("SHA-256 hash is not 64 characters long")
# Out:
# MD5 hash is consistent
# MD5 hash is 32 characters long
# SHA-1 hash is consistent
# SHA-1 hash is 40 characters long
# SHA-256 hash is consistent
# SHA-256 hash is 64 characters long

# %% [markdown]
# 2.7.6 Program to Demonstrate a Simple Implementation of a Blockchain Using
# Hash Codes as a Chain of Blocks

# %%
import hashlib
import datetime

class Block:
    def __init__(self, timestamp, data, previous_hash):
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        hash_string = str(self.timestamp) + str(self.data) + str(self.previous_hash)
        return hashlib.sha256(hash_string.encode()).hexdigest()

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block(datetime.datetime.now(), "Genesis Block", "0")

    def get_latest_block(self):
        return self.chain[-1]

    def add_block(self, new_block):
        new_block.previous_hash = self.get_latest_block().hash
        new_block.hash = new_block.calculate_hash()
        self.chain.append(new_block)

    def is_valid(self):
        for i in range(1, len(self.chain)):
            current_block = self.chain[i]
            previous_block = self.chain[i-1]

            if current_block.hash != current_block.calculate_hash():
                return False

            if current_block.previous_hash != previous_block.hash:
                return False

        return True

# Create a blockchain and add blocks
blockchain = Blockchain()
blockchain.add_block(Block(datetime.datetime.now(), "Block 1", ""))
blockchain.add_block(Block(datetime.datetime.now(), "Block 2", ""))
blockchain.add_block(Block(datetime.datetime.now(), "Block 3", ""))

# Check if the blockchain is valid
print("Is blockchain valid?", blockchain.is_valid())

# Manipulating the blockchain (introducing an invalid block)
blockchain.chain[1].data = "Modified Block"

# Check if the manipulated blockchain is valid
print("Is manipulated blockchain valid?", blockchain.is_valid())
# Out:
# Is blockchain valid? True
# Is manipulated blockchain valid? False

# %% [markdown]
# 2.7.7 Program to Demonstrate the Mining Process in Blockchain
